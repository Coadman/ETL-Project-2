# %%
import pandas as pd
import numpy as np

# %%
contacts = pd.read_csv('contacts.csv')
contacts_df = pd.DataFrame(contacts)
contacts_df.head()
# Out:
#    contact_id               name                         email
# 0        4661    Cecilia Velasco  cecilia.velasco@rodrigues.fr
# 1        3765      Mariana Ellis       mariana.ellis@rossi.org
# 2        4187        Sofie Woods       sofie.woods@riviere.com
# 3        4941  Jeanette Iannotti   jeanette.iannotti@yahoo.com
# 4        2199     Samuel Sorgatz      samuel.sorgatz@gmail.com

# %%
crowdfunding_campaigns = pd.read_csv('crowdfunding.csv')
crowdfunding_df = pd.DataFrame(crowdfunding_campaigns)
crowdfunding_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb    goal  pledged     outcome  \
# 0           Pre-emptive tertiary standardization     100        0      failed
# 1               Managed bottom-line architecture    1400    14560  successful
# 2   Function-based leadingedge pricing structure  108400   142523  successful
# 3  Vision-oriented fresh-thinking conglomeration    4200     2477      failed
# 4                      Proactive foreground core    7600     5265      failed
#
#    backers_count country currency  launched_at    deadline  staff_pick  \
# 0              0      CA      CAD   1581573600  1614578400       False
# ...

# %%
contacts.dtypes
# Out:
# contact_id     int64
# name          object
# email         object
# dtype: object

# %%
crowdfunding_campaigns.dtypes
# Out:
# cf_id                       int64
# contact_id                  int64
# company_name               object
# blurb                      object
# goal                        int64
# pledged                     int64
# outcome                    object
# backers_count               int64
# country                    object
# currency                   object
# launched_at                 int64
# deadline                    int64
# staff_pick                   bool
# spotlight                    bool
# category & sub-category    object
# dtype: object

# %%
# Convert the goal and pledged columns to a `float` data type.
crowdfunding_df[["goal","pledged"]] = crowdfunding_df[["goal","pledged"]].astype(float)
crowdfunding_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# 4                      Proactive foreground core    7600.0    5265.0
#
#       outcome  backers_count country currency  launched_at    deadline  \
# 0      failed              0      CA      CAD   1581573600  1614578400
# 1  successful            158      US      USD   1611554400  1621918800
# ...

# %%
# Converting Dates

from datetime import datetime as dt
crowdfunding_df["launched_at"] = pd.to_datetime(crowdfunding_df["launched_at"],unit='s').dt.strftime('%Y-%m-%d')
crowdfunding_df["deadline"] = pd.to_datetime(crowdfunding_df["deadline"],unit='s').dt.strftime('%Y-%m-%d')
crowdfunding_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# 4                      Proactive foreground core    7600.0    5265.0
#
#       outcome  backers_count country currency launched_at    deadline  \
# 0      failed              0      CA      CAD  2020-02-13  2021-03-01
# 1  successful            158      US      USD  2021-01-25  2021-05-25
# ...

# %%
# Splitting Names And Dropping the Name Header
#split names
contacts_df['first_name'] = contacts_df['name'].str.split().str[0]
contacts_df['last_name'] = contacts_df['name'].str.split().str[-1]

contacts_df.drop('name', axis=1, inplace=True)

contacts_df.head()
# Out:
#    contact_id                         email first_name last_name
# 0        4661  cecilia.velasco@rodrigues.fr    Cecilia   Velasco
# 1        3765       mariana.ellis@rossi.org    Mariana     Ellis
# 2        4187       sofie.woods@riviere.com      Sofie     Woods
# 3        4941   jeanette.iannotti@yahoo.com   Jeanette  Iannotti
# 4        2199      samuel.sorgatz@gmail.com     Samuel   Sorgatz

# %%
# Assign the category and subcategory values to category and subcategory columns.
crowdfunding_df[["category","subcategory"]] = crowdfunding_df["category & sub-category"].str.split('/', n=1, expand=True)
crowdfunding_df.head(10)
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
# 5   2057        5650                 Harris Group
# 6   1894        5889  Ortiz, Coleman and Mitchell
# 7   2669        4842                Carter-Guzman
# 8   1114        3280               Nunez-Richards
# 9    970        5468       Rangel, Holt and Jones
#
#                                            blurb      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# ...

# %%
# Get the unique categories and subcategories in separate lists.
categories = crowdfunding_df['category'].unique().tolist()
subcategories = crowdfunding_df['subcategory'].unique().tolist()

# %%
# Create numpy arrays that have 1-10 for the category_ids and 1-25 for the subcategory_ids.
category_ids = np.arange(1, 10)
subcategory_ids = np.arange(1, 25)

# Use a list comprehension to add "cat0" to each category_id. 
cat_ids = ["cat0" + str(cat_id) for cat_id in category_ids]

# Use a list comprehension to add "scat0" to each subcategory_id. 
scat_ids = ["sub_cat0" + str(scat_id) for scat_id in subcategory_ids ]

print(cat_ids)
print(scat_ids)
# Out:
# ['cat01', 'cat02', 'cat03', 'cat04', 'cat05', 'cat06', 'cat07', 'cat08', 'cat09']
# ['sub_cat01', 'sub_cat02', 'sub_cat03', 'sub_cat04', 'sub_cat05', 'sub_cat06', 'sub_cat07', 'sub_cat08', 'sub_cat09', 'sub_cat010', 'sub_cat011', 'sub_cat012', 'sub_cat013', 'sub_cat014', 'sub_cat015', 'sub_cat016', 'sub_cat017', 'sub_cat018', 'sub_cat019', 'sub_cat020', 'sub_cat021', 'sub_cat022', 'sub_cat023', 'sub_cat024']

# %%
# Create a category DataFrame with the cat_ids array as the category_id and categories list as the category name.
category_df = pd.DataFrame({
    "category_id": cat_ids,
    "category" : categories
})
# Create a subcategory DataFrame with the scat_ids array as the subcategory_id and subcategories list as the subcategory name.
subcategory_df = pd.DataFrame({
    "subcategory_id": scat_ids,
    "subcategory" : subcategories
})

category_df.head(10)
# Out:
#   category_id      category
# 0       cat01          food
# 1       cat02         music
# 2       cat03    technology
# 3       cat04       theater
# 4       cat05  film & video
# 5       cat06    publishing
# 6       cat07         games
# 7       cat08   photography
# 8       cat09    journalism

# %%
subcategory_df.head(10)
# Out:
#   subcategory_id     subcategory
# 0      sub_cat01     food trucks
# 1      sub_cat02            rock
# 2      sub_cat03             web
# 3      sub_cat04           plays
# 4      sub_cat05     documentary
# 5      sub_cat06  electric music
# 6      sub_cat07           drama
# 7      sub_cat08      indie rock
# 8      sub_cat09       wearables
# 9     sub_cat010      nonfiction

# %%
# Merge the campaign_df with the category_df on the "category" column and 
# the subcategory_df on the "subcategory" column.
crowdfunding_merged_df = crowdfunding_df.merge(category_df, on='category', how='left').merge(subcategory_df, on='subcategory', how='left')
crowdfunding_merged_df.tail(10)
# Out:
#      cf_id  contact_id                  company_name  \
# 990   1561        5500                 Ortiz-Roberts
# 991   2632        3494                   Ramirez LLC
# 992    439        3924                    Morrow Inc
# 993    461        3521               Erickson-Rogers
# 994   1419        5262         Leach, Rich and Price
# 995   2986        3684              Manning-Hamilton
# 996   2031        5784                    Butler LLC
# 997   1627        1498                      Ball LLC
# 998   2175        6073   Taylor, Santiago and Flores
# 999   1788        4939  Hernandez, Norton and Kelley
#
#                                         blurb      goal   pledged     outcome  \
# 990      Devolved foreground customer loyalty    7800.0    6839.0      failed
# 991            Reduced reciprocal focus group    9800.0   11091.0  successful
# 992                Networked global migration    3100.0   13223.0  successful
# ...

# %%
# rename the "blurb", "launched_at", and "deadline" columns
crowdfunding_df = crowdfunding_df.rename(columns={'launched_at': 'launch_date', 'blurb':'description', 'deadline': 'end_date'})
crowdfunding_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                      description      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# 4                      Proactive foreground core    7600.0    5265.0
#
#       outcome  backers_count country currency launch_date    end_date  \
# 0      failed              0      CA      CAD  2020-02-13  2021-03-01
# 1  successful            158      US      USD  2021-01-25  2021-05-25
# ...

# %%
contacts_df.to_csv("contacts_transformed.csv", encoding='utf8', index=False)
crowdfunding_df.to_csv("crowdfunding_transformed.csv", encoding='utf8', index=False)
category_df.to_csv("category.csv", encoding='utf8', index=False)
subcategory_df.to_csv("subcategory.csv", encoding='utf8', index=False)
